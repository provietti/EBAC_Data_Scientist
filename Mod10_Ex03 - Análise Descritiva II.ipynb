# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
#importando bibliotecas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#carregando os dados
df_renda = pd.read_csv('Profissão- Cientista de Dados_M10_support material.csv', sep = ',', decimal='.')
#excluindo colunas desnecessárias
del df_renda['Unnamed: 0']
del df_renda['index']
# exibindo as 5 primeiras linhas do df filtrado:
df_renda.head()
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# 0       3.575342                    3.0  False  3369.24
# ...

# %%
df_renda.dtypes
# Out:
# data_ref                  object
# sexo                      object
# posse_de_veiculo            bool
# posse_de_imovel             bool
# qtd_filhos                 int64
# tipo_renda                object
# educacao                  object
# estado_civil              object
# tipo_residencia           object
# idade                      int64
# tempo_emprego            float64
# qt_pessoas_residencia    float64
# mau                         bool
# renda                    float64
# dtype: object

# %%
po

# %%
tick_lab = df_renda.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'sexo'
        , data=df_renda)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
tick_lab = df_renda.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'posse_de_veiculo'
        , data=df_renda)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
tick_lab = df_renda.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'posse_de_imovel'
        , data=df_renda)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
tick_lab = df_renda.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'tipo_renda'
        , data=df_renda)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
tick_lab = df_renda.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'estado_civil'
        , data=df_renda)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
tick_lab = df_renda.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'tipo_residencia'
        , data=df_renda)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %%
tick_lab = df_renda.data_ref.unique()

ax=sns.countplot(
        x='data_ref'
        , hue = 'educacao'
        , data=df_renda)

ax.set_xticklabels(tick_lab, rotation=90)
# Out:
# [Text(0, 0, '2015-01-01'),
#  Text(1, 0, '2015-02-01'),
#  Text(2, 0, '2015-03-01'),
#  Text(3, 0, '2015-04-01'),
#  Text(4, 0, '2015-05-01'),
#  Text(5, 0, '2015-06-01'),
#  Text(6, 0, '2015-07-01'),
#  Text(7, 0, '2015-08-01'),
#  Text(8, 0, '2015-09-01'),
#  Text(9, 0, '2015-10-01'),
#  Text(10, 0, '2015-11-01'),
#  Text(11, 0, '2015-12-01'),
#  Text(12, 0, '2016-01-01'),
#  Text(13, 0, '2016-02-01'),
#  Text(14, 0, '2016-03-01')]

# %% [markdown]
# Houve uma mudança na escolaridade das pessoas na base de dados a partir de 09/2015. O número de pessoas com nível secundário de educação caiu bastante enquanto o nível superior aumentou. Essa mudança merece ser investigada.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'sexo',
                   data=df_renda, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df_renda['data_ref'].unique()

ticks = ax.set_xticks(list(range(df_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_veiculo',
                   data=df_renda, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df_renda['data_ref'].unique()

ticks = ax.set_xticks(list(range(df_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'posse_de_imovel',
                   data=df_renda, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df_renda['data_ref'].unique()

ticks = ax.set_xticks(list(range(df_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_renda',
                   data=df_renda, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df_renda['data_ref'].unique()

ticks = ax.set_xticks(list(range(df_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %%
df_renda.tipo_renda.value_counts()
# Out:
# Assalariado         7826
# Empresário          3311
# Pensionista         2543
# Servidor público    1316
# Bolsista               4
# Name: tipo_renda, dtype: int64

# %% [markdown]
# Há certa instabilidade nesta variável quando se observa os perfis de médias dos bolsistas e servidores públicos

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'educacao',
                   data=df_renda, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df_renda['data_ref'].unique()

ticks = ax.set_xticks(list(range(df_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %% [markdown]
# Há  instabilidade nesta variável quando se observa os perfis de médias de quem tem pós-graduação.

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'estado_civil',
                   data=df_renda, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df_renda['data_ref'].unique()

ticks = ax.set_xticks(list(range(df_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %% [markdown]
# há instabilidade nestes perfis de média, não usaria esta variável no modelo.

# %%
ax = sns.pointplot(x="data_ref", y="renda", hue = 'tipo_residencia',
                   data=df_renda, dodge=True, ci = 95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.30),ncol = 3)

tick_labs = df_renda['data_ref'].unique()

#ticks = ax.set_xticks(list(range(df_renda['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs, rotation=90)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.50),ncol = 3)

# %% [markdown]
# Há instabilidade nesta variável quando se observa os perfis de média de quem tem renda do tipo comunitário
