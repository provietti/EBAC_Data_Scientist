# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r = requests.get(url)
data_json = r.json()
df = pd.DataFrame(data_json['items'])

df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0      12410           Estado  Rio de Janeiro        33  RJ    None
# 1      10561           Estado  Rio de Janeiro        33  RJ    None
# 2       7150           Estado  Rio de Janeiro        33  RJ    None
# 3       9050           Estado  Rio de Janeiro        33  RJ    None
# 4       8556           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001680/2011-92
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001228/2011-21
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000508/2012-01
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000893/2010-16
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
# 2) Seu código aqui
df['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %% [markdown]
# Os três status mais frequente das solicitações são "Encaminhado à PGFN com manifestação técnica favorável]'(34 ocorrências), "Deferido" (14 ocorrências) e "Arquivado a pedido" (3 ocorrências)

# %%
# 3) Seu código aqui

ano = df["data_status"]

ano = ano.str.slice(start=-4)

ano
# Out:
# 0     2012
# 1     2012
# 2     2013
# 3     2011
# 4     2011
# 5     2006
# 6     2009
# 7     2016
# 8     2012
# 9     2002
# 10    2011
# 11    2011
# 12    2009
# 13    2012
# 14    2009
# 15    2012
# 16    2012
# 17    2012
# 18    2014
# 19    2013
# 20    2002
# 21    2009
# 22    2002
# 23    2013
# 24    2013
# 25    2013
# 26    2013
# 27    2009
# 28    2011
# 29    2008
# 30    2009
# 31    2012
# 32    2010
# 33    2011
# 34    2016
# 35    2009
# 36    2002
# 37    2009
# 38    2014
# 39    2010
# 40    2016
# 41    2006
# 42    2012
# 43    2010
# 44    2012
# 45    2013
# 46    2012
# 47    2014
# 48    2014
# 49    2008
# 50    2016
# 51    2009
# Name: data_status, dtype: object

# %%
# 4)

ano.value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2016     4
# 2002     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: data_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_pvl(estado, interessado):
    uf = estado
    tipo = interessado
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=' + uf +'&tipo_interessado=' + tipo
    
    r = requests.get(url)
    data_json = r.json()
    df = pd.DataFrame(data_json['items'])

    return df

# %%
df = consulta_pvl('MG','Estado')
df.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0      22380           Estado  Minas Gerais        31  MG
# 1      13447           Estado  Minas Gerais        31  MG
# 2      13587           Estado  Minas Gerais        31  MG
# 3      13672           Estado  Minas Gerais        31  MG
# 4       5582           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0  00000.000000/2031-07                                 Arquivado pela STN
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4                  None                                 Arquivado a pedido
#
#            num_processo        data_protocolo  \
# 0  17944.000547/2016-23  2016-12-21T02:00:00Z
# 1  19405.000002/2006-78  2009-02-02T02:00:00Z
# ...

# %%
# 2) Seu código aqui

selecao = df['status'] == 'Arquivado por decurso de prazo'

df[selecao]['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    1
# Name: status, dtype: int64

# %%
df = consulta_pvl('BA', "Município")

df.head()
# Out:
#    id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0      48069        Município            Santanópolis   2928307  BA
# 1      42512        Município  Santo Antônio de Jesus   2928703  BA
# 2      38012        Município            Dias d'Ávila   2910057  BA
# 3      44789        Município             Cristópolis   2909703  BA
# 4      42877        Município      Brotas de Macaúbas   2904506  BA
#
#                 num_pvl             status          num_processo  \
# 0  PVL02.003564/2021-17         Em análise  17944.103756/2021-95
# 1  PVL02.001085/2020-85  Deferido (PVL-IF)                  None
# 2  PVL02.003880/2019-74           Deferido  17944.103514/2019-87
# 3  PVL02.001040/2021-91  Deferido (PVL-IF)                  None
# 4  PVL02.001388/2020-06  Deferido (PVL-IF)                  None
#
#          data_protocolo                                      tipo_operacao  \
# 0  2022-05-17T21:16:44Z  Operação contratual interna (com garantia da U...
# ...

# %%
df.status.unique()
# Out:
# array(['Em análise', 'Deferido (PVL-IF)', 'Deferido',
#        'Arquivado por decurso de prazo',
#        'Em retificação pelo interessado',
#        'Encaminhado à PGFN com manifestação técnica favorável',
#        'Arquivado a pedido', 'Regularizado', 'Indeferido', 'Arquivado',
#        'Pendente de regularização', 'Em retificação pelo credor',
#        'Em análise (PVL-IF)', 'Indeferido (PVL-IF)',
#        'Processo pendente de distribuição', 'Arquivado a pedido (PVL-IF)',
#        'Arquivado pela STN', 'Em retificação pelo interessado (PVL-IF)',
#        'Encaminhado à PGFN (decisão judicial)'], dtype=object)

# %%
# 3) Seu código aqui

selecao = (df['status'] == 'Deferido')| (df['status'] == 'Deferido (PVL-IF)')

df[selecao]['interessado'].value_counts()
# Out:
# Luís Eduardo Magalhães       14
# Vitória da Conquista         11
# Camaçari                     10
# Lauro de Freitas             10
# Bom Jesus da Lapa             8
#                              ..
# Feira da Mata                 1
# Ruy Barbosa                   1
# Aramari                       1
# Crisópolis                    1
# Presidente Tancredo Neves     1
# Name: interessado, Length: 203, dtype: int64

# %% [markdown]
# O município com mais pedidos deferidos é Luís Eduardo Magalhães

# %%
df = consulta_pvl('BA', "Estado")

df.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0       8733           Estado       Bahia        29  BA                  None
# 1      11497           Estado       Bahia        29  BA                  None
# 2      10659           Estado       Bahia        29  BA                  None
# 3       8858           Estado       Bahia        29  BA                  None
# 4      45396           Estado       Bahia        29  BA  PVL02.001082/2021-22
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000833/2010-01
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001461/2013-75
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.001253/2012-95
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000853/2014-06
# 4                    Em retificação pelo interessado  17944.102529/2021-42
#
# ...

# %%
# 4) Seu código aqui

df.to_csv('PVL_Bahia.csv')
